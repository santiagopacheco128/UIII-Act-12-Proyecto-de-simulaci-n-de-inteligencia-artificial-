# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagopacheco128/UIII-Act-12-Proyecto-de-simulaci-n-de-inteligencia-artificial-/blob/main/UIII_Act_12_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_santiago_0113_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Santiago Pacheco fecha 27/05/2026
# ## clase: guardia
# ![texto del vínculo](https://raw.githubusercontent.com/santiagopacheco128/UIII-Act-12-Proyecto-de-simulaci-n-de-inteligencia-artificial-/refs/heads/main/ChatGPT%20Image%2027%20may%202026%2C%2008_21_05%20a.m..png)

# %%
# ============================================
# Sistema Inteligente de Guardias 🛡️
# Programación Orientada a Objetos
# ============================================

class Guardia:

    # CONSTRUCTOR
    def __init__(self, empresa, puesto, equipo, turno, protocolos, capacitacion):

        self.empresa = empresa
        self.puesto = puesto
        self.equipo = equipo
        self.turno = turno
        self.protocolos = protocolos
        self.capacitacion = capacitacion


    # FUNCIÓN AGREGAR
    def agregar_guardia(lista_guardias):

        print("\n📌 AGREGAR GUARDIA")

        empresa = input("Empresa de seguridad: ")
        puesto = input("Puesto de vigilancia: ")
        equipo = input("Equipo de comunicación: ")
        turno = input("Turno: ")
        protocolos = input("Protocolos de acceso: ")
        capacitacion = input("Capacitación: ")

        guardia = Guardia(
            empresa,
            puesto,
            equipo,
            turno,
            protocolos,
            capacitacion
        )

        lista_guardias.append(guardia)

        print("✅ Guardia agregado correctamente")


    # FUNCIÓN LISTAR
    def listar_guardias(lista_guardias):

        print("\n📋 LISTA DE GUARDIAS")

        if len(lista_guardias) == 0:

            print("❌ No hay guardias registrados")

        else:

            print("--------------------------------------------------------------------------------------------------")
            print(f"{'EMPRESA':15} {'PUESTO':20} {'EQUIPO':18} {'TURNO':10} {'PROTOCOLOS':15} {'CAPACITACIÓN':15}")
            print("--------------------------------------------------------------------------------------------------")

            for guardia in lista_guardias:

                print(f"{guardia.empresa:15} {guardia.puesto:20} {guardia.equipo:18} {guardia.turno:10} {guardia.protocolos:15} {guardia.capacitacion:15}")

            print("--------------------------------------------------------------------------------------------------")


    # FUNCIÓN ACTUALIZAR
    def actualizar_guardia(lista_guardias):

        print("\n✏️ ACTUALIZAR GUARDIA")

        empresa_buscar = input("Ingresa la empresa del guardia: ")

        for guardia in lista_guardias:

            if guardia.empresa == empresa_buscar:

                print("✅ Guardia encontrado")

                guardia.puesto = input("Nuevo puesto de vigilancia: ")
                guardia.equipo = input("Nuevo equipo de comunicación: ")
                guardia.turno = input("Nuevo turno: ")
                guardia.protocolos = input("Nuevos protocolos de acceso: ")
                guardia.capacitacion = input("Nueva capacitación: ")

                print("✅ Información actualizada")
                return

        print("❌ Guardia no encontrado")


    # FUNCIÓN BORRAR
    def borrar_guardia(lista_guardias):

        print("\n🗑️ BORRAR GUARDIA")

        empresa_buscar = input("Ingresa la empresa del guardia: ")

        for guardia in lista_guardias:

            if guardia.empresa == empresa_buscar:

                lista_guardias.remove(guardia)

                print("✅ Guardia eliminado correctamente")
                return

        print("❌ Guardia no encontrado")


# LISTA
lista_guardias = []


# MENÚ PRINCIPAL
while True:

    print("\n================================")
    print("🛡️ SISTEMA INTELIGENTE DE GUARDIAS")
    print("================================")
    print("1. Agregar guardia")
    print("2. Listar guardias")
    print("3. Actualizar guardia")
    print("4. Borrar guardia")
    print("5. Salir")

    opcion = input("Selecciona una opción: ")


    if opcion == "1":

        Guardia.agregar_guardia(lista_guardias)


    elif opcion == "2":

        Guardia.listar_guardias(lista_guardias)


    elif opcion == "3":

        Guardia.actualizar_guardia(lista_guardias)


    elif opcion == "4":

        Guardia.borrar_guardia(lista_guardias)


    elif opcion == "5":

        print("👋 Saliendo del sistema...")
        print("Programa realizado por Santiago Ernesto Pacheco Holguin")
        print("Profesor: Elizeo Nava")
        break


    else:

        print("❌ Opción inválida")
# Out:
# ...
# 🛡️ SISTEMA INTELIGENTE DE GUARDIAS
# ...
# 1. Agregar guardia
# 2. Listar guardias
# 3. Actualizar guardia
# 4. Borrar guardia
# 5. Salir
# Selecciona una opción: 1
#
# 📌 AGREGAR GUARDIA
# Empresa de seguridad: cp
# Puesto de vigilancia: entrada principal
# Equipo de comunicación: radio cp
# Turno: matutino
# Protocolos de acceso: A
# Capacitación: basica
# ✅ Guardia agregado correctamente
#
# ...
# 🛡️ SISTEMA INTELIGENTE DE GUARDIAS
# ...
# 1. Agregar guardia
# 2. Listar guardias
# 3. Actualizar guardia
# 4. Borrar guardia
# 5. Salir
# Selecciona una opción: 1
#
# 📌 AGREGAR GUARDIA
# Empresa de seguridad: segurymax
# Puesto de vigilancia: trasero
# Equipo de comunicación: radio telcel
# Turno: nocturno
# Protocolos de acceso: B
# Capacitación: basica
# ✅ Guardia agregado correctamente
#
# ...
# 🛡️ SISTEMA INTELIGENTE DE GUARDIAS
# ...
# 1. Agregar guardia
# 2. Listar guardias
# 3. Actualizar guardia
# 4. Borrar guardia
# 5. Salir
# Selecciona una opción: 1
#
# 📌 AGREGAR GUARDIA
# Empresa de seguridad: poop
# ...
